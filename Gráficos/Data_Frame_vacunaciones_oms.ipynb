# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciaapenat/TFM/blob/main/Gr%C3%A1ficos/Data_Frame_vacunaciones_oms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clonación del Repositorio GitHub de **TFM**
#
# ---

# %%
! git clone https://github.com/patriciaapenat/TFM.git
# Out:
# Cloning into 'TFM'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 258 (delta 87), reused 79 (delta 44), pack-reused 104
# Receiving objects: 100% (258/258), 10.39 MiB | 14.45 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %% [markdown]
# Importo algunas librerias de pandas

# %%
import pandas as pd
import numpy as np
# !pip install plotly==4.14.3
# Out:
# Collecting plotly==4.14.3
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 73.7 MB/s eta 0:00:00
# Collecting retrying>=1.3.3 (from plotly==4.14.3)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from plotly==4.14.3) (1.16.0)
# Installing collected packages: retrying, plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.13.1
#     Uninstalling plotly-5.13.1:
#       Successfully uninstalled plotly-5.13.1
# Successfully installed plotly-4.14.3 retrying-1.3.4

# %%
#from chart_studio import plotly
from plotly import tools
import plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
from IPython.display import HTML, Image
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Acceso al dataset de la OMS que a partir de ahora se llamará **df_vacunation**

# %%
df_vacunation =pd.read_csv ('/content/TFM/Ficheros_Depurados/df_vacunation.csv')

df_vacunation.head()
# Out:
#       PAIS PAIS_ISO3     CONTINENTE ISO_CONTINENTE OMS_REGION FUENTE_DATOS  \
# 0  Algeria       DZA         Africa             AF       AFRO    REPORTING
# 1   Angola       AGO         Africa             AF       AFRO    REPORTING
# 2  Armenia       ARM           Asia             AS       EURO    REPORTING
# 3    Aruba       ABW  North America            NaN       AMRO    REPORTING
# 4   Brazil       BRA  South America             SA       AMRO    REPORTING
#
#   FECHA_ULT_ACTUALIZACION  TOTAL_VACUNACION_ACUM  NPER_VACUNADAS_1DOSIS  \
# 0              04-09-2022             15267442.0                7840131
# 1              18-06-2023             25962530.0               15980639
# 2              04-06-2023              2158796.0                1122646
# 3              02-06-2023               216974.0                  90449
# 4              02-06-2023            513329718.0              188746389
#
#    TOTAL_VACUNACION_PER100  NPER_VACUNADAS_1DOSIS_PER100  \
# 0                   34.817                        17.879
# 1                   78.994                        48.623
# 2                   72.900                        37.886
# 3                  203.224                        84.717
# 4                  241.499                        88.797
#
#    NPER_VACUNADAS_DOSIS_FULL  NPER_VACUNADAS_DOSIS_FULL_PER100  \
# 0                    6481186                            14.780
# 1                    9010599                            27.416
# 2                     996804                            33.639
# 3                      84297                            78.955
# 4                  171459392                            80.664
#
#   FECHA_PRIMERA_VACUNA  N_TIPOS_VACUNAS_USADAS  NPER_CON_DOSIS_ADICIONAL  \
# 0           30-01-2021                     4.0                  575651.0
# 1           10-03-2021                     1.0                 2220003.0
# 2           27-01-2021                    10.0                   45446.0
# 3           17-02-2021                     2.0                   35659.0
# 4           17-01-2021                     5.0               110382337.0
#
#    NPER_CON_DOSIS_ADIDICIONAL_PER100
# 0                              1.313
# 1                              6.755
# 2                              1.534
# 3                             33.399
# 4                             51.930

# %%
df_vacunation=df_vacunation.fillna('NA')
df_vacunation.head()
# Out:
#       PAIS PAIS_ISO3     CONTINENTE ISO_CONTINENTE OMS_REGION FUENTE_DATOS  \
# 0  Algeria       DZA         Africa             AF       AFRO    REPORTING
# 1   Angola       AGO         Africa             AF       AFRO    REPORTING
# 2  Armenia       ARM           Asia             AS       EURO    REPORTING
# 3    Aruba       ABW  North America             NA       AMRO    REPORTING
# 4   Brazil       BRA  South America             SA       AMRO    REPORTING
#
#   FECHA_ULT_ACTUALIZACION  TOTAL_VACUNACION_ACUM  NPER_VACUNADAS_1DOSIS  \
# 0              04-09-2022             15267442.0                7840131
# 1              18-06-2023             25962530.0               15980639
# 2              04-06-2023              2158796.0                1122646
# 3              02-06-2023               216974.0                  90449
# 4              02-06-2023            513329718.0              188746389
#
#    TOTAL_VACUNACION_PER100  NPER_VACUNADAS_1DOSIS_PER100  \
# 0                   34.817                        17.879
# 1                   78.994                        48.623
# 2                   72.900                        37.886
# 3                  203.224                        84.717
# 4                  241.499                        88.797
#
#    NPER_VACUNADAS_DOSIS_FULL  NPER_VACUNADAS_DOSIS_FULL_PER100  \
# 0                    6481186                            14.780
# 1                    9010599                            27.416
# 2                     996804                            33.639
# 3                      84297                            78.955
# 4                  171459392                            80.664
#
#   FECHA_PRIMERA_VACUNA  N_TIPOS_VACUNAS_USADAS  NPER_CON_DOSIS_ADICIONAL  \
# 0           30-01-2021                     4.0                  575651.0
# 1           10-03-2021                     1.0                 2220003.0
# 2           27-01-2021                    10.0                   45446.0
# 3           17-02-2021                     2.0                   35659.0
# 4           17-01-2021                     5.0               110382337.0
#
#    NPER_CON_DOSIS_ADIDICIONAL_PER100
# 0                              1.313
# 1                              6.755
# 2                              1.534
# 3                             33.399
# 4                             51.930

# %%
df.groupby(["CONTINENTE"]).count()["PAIS"]
# Out:
# CONTINENTE
# Africa            55
# Asia              46
# Europe            48
# North America     36
# Oceania           23
# Sin Determinar     7
# South America     14
# Name: PAIS, dtype: int64

# %%
groupby_continente=df.groupby(["CONTINENTE"]).count()["PAIS"]

# %%
# prepare data frame
df_vacunation = df.iloc[:5,:]

# import graph objects as "go"
import plotly.graph_objs as go

# Creating trace1
trace1 = go.Scatter(
                    x = df.CONTINENTE,
                    y = df.NPER_VACUNADAS_DOSIS_FULL,
                    mode = "lines",
                    name = "N Vacunation_Full",
                    marker = dict(color = 'rgba(16, 112, 2, 0.8)'),
                    text= df.PAIS)
# Creating trace2
trace2 = go.Scatter(
                    x = df.CONTINENTE,
                    y = df.NPER_VACUNADAS_1DOSIS,
                    mode = "lines+markers",
                    name = "N Vacunation_1Dosis",
                    marker = dict(color = 'rgba(80, 26, 80, 0.8)'),
                    text= df.CONTINENTE)
data = [trace1, trace2]
layout = dict(title = 'Citation and Teaching vs World Rank of Top 100 Universities',
              xaxis= dict(title= 'World Rank',ticklen= 5,zeroline= False)
             )
fig = dict(data = data, layout = layout)
iplot(fig,filename='Basic Distplot')
# Out:
# <div>                            <div id="d695313f-79e4-4f1c-859b-4047f29f320e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d695313f-79e4-4f1c-859b-4047f29f320e")) {                    Plotly.newPlot(                        "d695313f-79e4-4f1c-859b-4047f29f320e",                        [{"marker": {"color": "rgba(16, 112, 2, 0.8)"}, "mode": "lines", "name": "N Vacunation_Full", "text": ["Algeria", "Angola", "Armenia", "Aruba", "Brazil", "Burkina Faso", "Costa Rica", "Dominica", "Finland", "French Guiana", "Gabon", "Haiti", "Iceland", "Jersey", "Lebanon", "Malaysia", "Marshall Islands", "Myanmar", "Oman", "Pakistan", "Republic of Moldova", "Saint Kitts and Nevis", "Slovenia", "Somalia", "Togo", "Tokelau", "Tunisia", "Vanuatu", "Andorra", "Anguilla", "Bahamas", "Barbados", "Belarus", "Belize", "Benin", "Bermuda", "Bolivia (Plurinational State of)", "Bonaire, Sint Eustatius and Saba", "Botswana", "Cambodia", "Cameroon", "Canada", "Chad", "Croatia", "French Polynesia", "Georgia", "Grenada", "Indonesia", "Iran (Islamic Republic of)", "Kenya", "Kosovo", "Liberia", "Madagascar", "Mauritania", "Nepal", "Argentina", "Australia", "Bahrain", "British Virgin Islands", "Egypt", "El Salvador", "Eswatini", "Greece", "Guam", "India", "Latvia", "Lesotho", "Luxembourg", "Montserrat", "Namibia", "Papua New Guinea", "Portugal", "Qatar", "Saudi Arabia", "Senegal", "Sint Maarten", "South Africa", "Sri Lanka", "United Arab Emirates", "United States of America", "Uzbekistan", "Wallis and Futuna", "American Samoa", "Austria", "Bangladesh", "Brunei Darussalam", "Bulgaria", "Central African Republic", "Cuba", "Cura\u00e7ao", "Ecuador", "Estonia", "Ethiopia", "Fiji", "Gambia", "Guadeloupe", "Honduras", "Ireland", "Jordan", "Libya", "Lithuania", "Malawi", "Maldives", "Malta", "Netherlands", "Niger", "Romania", "Saint Vincent and the Grenadines", "Slovakia", "Solomon Islands", "Sudan", "Tonga", "United Republic of Tanzania", "Uruguay", "Venezuela (Bolivarian Republic of)", "Zambia", "Zimbabwe", "Albania", "Chile", "Congo", "C\u00f4te d\u2019Ivoire", "Denmark", "Greenland", "Guernsey", "Guinea", "Guinea-Bissau", "Guyana", "Hungary", "Japan", "Kyrgyzstan", "Mauritius", "Mongolia", "North Macedonia", "Seychelles", "Trinidad and Tobago", "Turkmenistan", "Uganda", "Ukraine", "Yemen", "New Caledonia", "Nigeria", "Niue", "occupied Palestinian territory", "Saba", "San Marino", "South Sudan", "Tajikistan", "Turks and Caicos Islands", "Antigua and Barbuda", "Bonaire", "Colombia", "Comoros", "Cyprus", "Democratic Republic of the Congo", "Equatorial Guinea", "Eritrea", "Ghana", "Iraq", "Isle of Man", "Jamaica", "Liechtenstein", "Mali", "Martinique", "Mexico", "Monaco", "Montenegro", "Morocco", "Mozambique", "Northern Mariana Islands (Commonwealth of the)", "Norway", "Panama", "Peru", "Poland", "Puerto Rico", "Sao Tome and Principe", "Suriname", "Azerbaijan", "Belgium", "Bhutan", "Bosnia and Herzegovina", "China", "Cook Islands", "Czechia", "Djibouti", "Dominican Republic", "Germany", "Gibraltar", "Guatemala", "Israel", "Kazakhstan", "Kuwait", "Lao People's Democratic Republic", "Micronesia (Federated States of)", "Rwanda", "Saint Helena, Ascension and Tristan da Cunha", "Saint Lucia", "Serbia", "Sweden", "Tuvalu", "Thailand", "The United Kingdom", "Turkey", "Afghanistan", "Burundi", "Cabo Verde", "Cayman Islands", "Falkland Islands (Malvinas)", "Faroe Islands", "France", "Italy", "Kiribati", "Nauru", "New Zealand", "Nicaragua", "Palau", "Paraguay", "Philippines", "Pitcairn Islands", "Republic of Korea", "Russian Federation", "Samoa", "Sierra Leone", "Singapore", "Sint Eustatius", "Spain", "Switzerland", "Syrian Arab Republic", "Timor-Leste", "Viet Nam"], "type": "scatter", "x": ["Africa", "Africa", "Asia", "North America", "South ...
