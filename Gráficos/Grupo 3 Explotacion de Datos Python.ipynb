# %% [markdown]
# Clonación del Repositorio GitHub de **TFM**
#
# ---

# %%
! git clone https://github.com/patriciaapenat/TFM.git
# Out:
# Cloning into 'TFM'...
# remote: Enumerating objects: 337, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 337 (delta 20), reused 1 (delta 1), pack-reused 307
# Receiving objects: 100% (337/337), 17.46 MiB | 10.64 MiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %% [markdown]
# Importo algunas librerias de pandas

# %%
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set()

#!pip install plotly==4.14.3

# %% [markdown]
# ##Visualización dinámica
# Instalación/carga librerías/datos utilizados

# %% [markdown]
# # Acceso al dataSet de Casos y Defunciones diarias **df_covid**

# %%
df_covid =pd.read_csv ('/content/TFM/Ficheros_Depurados/df_covid_daily_new.csv')
df_covid.head(10)
# Out:
#       PAIS_NOM PAIS_ISO3 PAIS_ISO2 FECHA_INFORMADA OMS_REGION  CASOS_NUEVOS  \
# 0  Afghanistan       AFG        AF      03-01-2020       EMRO             0
# 1  Afghanistan       AFG        AF      04-01-2020       EMRO             0
# 2  Afghanistan       AFG        AF      05-01-2020       EMRO             0
# 3  Afghanistan       AFG        AF      06-01-2020       EMRO             0
# 4  Afghanistan       AFG        AF      07-01-2020       EMRO             0
# 5  Afghanistan       AFG        AF      08-01-2020       EMRO             0
# 6  Afghanistan       AFG        AF      09-01-2020       EMRO             0
# 7  Afghanistan       AFG        AF      10-01-2020       EMRO             0
# 8  Afghanistan       AFG        AF      11-01-2020       EMRO             0
# 9  Afghanistan       AFG        AF      12-01-2020       EMRO             0
#
#    CASOS_ACUM  MUERTES_NUEVAS  MUERTES_ACUM
# 0           0               0             0
# 1           0               0             0
# 2           0               0             0
# 3           0               0             0
# 4           0               0             0
# 5           0               0             0
# 6           0               0             0
# 7           0               0             0
# 8           0               0             0
# 9           0               0             0

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301701 entries, 0 to 301700
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   PAIS_NOM         301701 non-null  object
#  1   PAIS_ISO3        301701 non-null  object
#  2   PAIS_ISO2        301701 non-null  object
#  3   FECHA_INFORMADA  301701 non-null  object
#  4   OMS_REGION       301701 non-null  object
#  5   CASOS_NUEVOS     301701 non-null  int64
#  6   CASOS_ACUM       301701 non-null  int64
#  7   MUERTES_NUEVAS   301701 non-null  int64
#  8   MUERTES_ACUM     301701 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 20.7+ MB

# %% [markdown]
# Gráfico de queso con la distribución de casos nuevos por continente. Para esto se agrupan los casos nuevos reportados a la fecha por continente y luego se procede a graficar.

# %%
df_covid.groupby(["OMS_REGION"]).sum()["CASOS_NUEVOS"]
# Out:
# <ipython-input-5-21699ca61600>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_covid.groupby(["OMS_REGION"]).sum()["CASOS_NUEVOS"]
# OMS_REGION
# AFRO       9540096
# AMRO     193094953
# EMRO      23383773
# EURO     275686519
# Other          764
# SEARO     61189014
# WPRO     204623604
# Name: CASOS_NUEVOS, dtype: int64

# %%
plt.pie(df_covid.groupby(["OMS_REGION"]).sum()["CASOS_NUEVOS"], labels=df_covid.groupby(["OMS_REGION"]).sum().index)
# Out:
# <ipython-input-6-590d75efec47>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.pie(df_covid.groupby(["OMS_REGION"]).sum()["CASOS_NUEVOS"], labels=df_covid.groupby(["OMS_REGION"]).sum().index)
# <ipython-input-6-590d75efec47>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.pie(df_covid.groupby(["OMS_REGION"]).sum()["CASOS_NUEVOS"], labels=df_covid.groupby(["OMS_REGION"]).sum().index)
# ([<matplotlib.patches.Wedge at 0x793819c009d0>,
#   <matplotlib.patches.Wedge at 0x793819c00880>,
#   <matplotlib.patches.Wedge at 0x793819c012d0>,
#   <matplotlib.patches.Wedge at 0x793819c01750>,
#   <matplotlib.patches.Wedge at 0x793819c01bd0>,
#   <matplotlib.patches.Wedge at 0x793819c01fc0>,
#   <matplotlib.patches.Wedge at 0x793819c02440>],
#  [Text(1.0991614387195137, 0.04294335375875052, 'AFRO'),
#   Text(0.7105937085530082, 0.8396764742237827, 'AMRO'),
#   Text(-0.20100187759705765, 1.081479655473212, 'EMRO'),
#   Text(-1.0854396895610747, 0.1783835203306565, 'EURO'),
#   Text(-0.6258596133315194, -0.9045992175546701, 'Other'),
#   Text(-0.3821264420364053, -1.0314937626067344, 'SEARO'),
#   Text(0.7362046384508083, -0.8173143399717852, 'WPRO')])

# %% [markdown]
# Gráfico de columnas con defunciones por región. Para esto se agrupan las defunciones reportadas a la fecha por región y luego se procede a graficar.
# Adicionalmente se ordena de manera descendente.

# %%
df_region_def = df_covid.groupby(["OMS_REGION"]).sum()["MUERTES_NUEVAS"]
df_region_def
# Out:
# <ipython-input-7-44d5d4b35115>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_region_def = df_covid.groupby(["OMS_REGION"]).sum()["MUERTES_NUEVAS"]
# OMS_REGION
# AFRO      175396
# AMRO     2956943
# EMRO      351341
# EURO     2243097
# Other         13
# SEARO     806441
# WPRO      413961
# Name: MUERTES_NUEVAS, dtype: int64

# %%
df_region_def = df_covid.groupby(['OMS_REGION']).agg(sum_def=("MUERTES_NUEVAS", 'sum'))
df_region_def = df_region_def.reset_index()
df_region_def
# Out:
#   OMS_REGION  sum_def
# 0       AFRO   175396
# 1       AMRO  2956943
# 2       EMRO   351341
# 3       EURO  2243097
# 4      Other       13
# 5      SEARO   806441
# 6       WPRO   413961

# %%
sns.barplot(x="OMS_REGION",y="sum_def",data=df_region_def,order=df_region_def.sort_values('sum_def',ascending=False).OMS_REGION)
# Out:
# <Axes: xlabel='OMS_REGION', ylabel='sum_def'>

# %% [markdown]
# Gráfico de líneas con tendencia de casos nuevos y acumulados en España. Para esto se filtra el df para obtener los registros de España exclusivamente, luego se procede a graficar.

# %%
df_Spain=df_covid[df_covid["PAIS_NOM"].str.contains("Spain")]
df_Spain
# Out:
#        PAIS_NOM PAIS_ISO3 PAIS_ISO2 FECHA_INFORMADA OMS_REGION  CASOS_NUEVOS  \
# 257146    Spain       ESP        ES      03-01-2020       EURO             0
# 257147    Spain       ESP        ES      04-01-2020       EURO             0
# 257148    Spain       ESP        ES      05-01-2020       EURO             0
# 257149    Spain       ESP        ES      06-01-2020       EURO             0
# 257150    Spain       ESP        ES      07-01-2020       EURO             0
# ...         ...       ...       ...             ...        ...           ...
# 258414    Spain       ESP        ES      24-06-2023       EURO             0
# 258415    Spain       ESP        ES      25-06-2023       EURO             0
# 258416    Spain       ESP        ES      26-06-2023       EURO             0
# 258417    Spain       ESP        ES      27-06-2023       EURO             0
# 258418    Spain       ESP        ES      28-06-2023       EURO             0
#
#         CASOS_ACUM  MUERTES_NUEVAS  MUERTES_ACUM
# 257146           0               0             0
# 257147           0               0             0
# 257148           0               0             0
# 257149           0               0             0
# 257150           0               0             0
# ...            ...             ...           ...
# 258414    13970616               0        121724
# 258415    13970616               0        121724
# 258416    13970616               0        121724
# 258417    13970616               0        121724
# 258418    13970616               0        121724
#
# [1273 rows x 9 columns]

# %%
sns.lineplot(data=df_Spain,x="FECHA_INFORMADA",y="CASOS_NUEVOS")
sns.lineplot(data=df_Spain,x="FECHA_INFORMADA",y="CASOS_ACUM")
# Out:
# <Axes: xlabel='FECHA_INFORMADA', ylabel='CASOS_NUEVOS'>

# %% [markdown]
# Gráfico de geolocalización con cantidad de defunciones por todos los países del mundo. Para esto se filtra el df por última fecha, para obtener los registros acumulados más recientes, luego se procede a graficar.

# %%
df_covid['FECHA_INFORMADA']= pd.to_datetime(df_covid['FECHA_INFORMADA'])
# Out:
# <ipython-input-17-9503698cf5b1>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_covid['FECHA_INFORMADA']= pd.to_datetime(df_covid['FECHA_INFORMADA'])

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301701 entries, 0 to 301700
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   PAIS_NOM         301701 non-null  object
#  1   PAIS_ISO3        301701 non-null  object
#  2   PAIS_ISO2        301701 non-null  object
#  3   FECHA_INFORMADA  301701 non-null  datetime64[ns]
#  4   OMS_REGION       301701 non-null  object
#  5   CASOS_NUEVOS     301701 non-null  int64
#  6   CASOS_ACUM       301701 non-null  int64
#  7   MUERTES_NUEVAS   301701 non-null  int64
#  8   MUERTES_ACUM     301701 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 20.7+ MB

# %%
df_last = df_covid.loc[(df_covid['FECHA_INFORMADA'] == '2023-07-06')]
df_last
# Out:
#                  PAIS_NOM PAIS_ISO3 PAIS_ISO2 FECHA_INFORMADA OMS_REGION  \
# 1251          Afghanistan       AFG        AF      2023-07-06       EMRO
# 2524              Albania       ALB        AL      2023-07-06       EURO
# 3797              Algeria       DZA        DZ      2023-07-06       AFRO
# 5070       American Samoa       ASM        AS      2023-07-06       WPRO
# 6343              Andorra       AND        AD      2023-07-06       EURO
# ...                   ...       ...       ...             ...        ...
# 296587            Vietnam       VNM        VN      2023-07-06       WPRO
# 297860  Wallis and Futuna       WLF        WF      2023-07-06       WPRO
# 299133              Yemen       YEM        YE      2023-07-06       EMRO
# 300406             Zambia       ZMB        ZM      2023-07-06       AFRO
# 301679           Zimbabwe       ZWE        ZW      2023-07-06       AFRO
#
#         CASOS_NUEVOS  CASOS_ACUM  MUERTES_NUEVAS  MUERTES_ACUM
# 1251             106      222274               0          7919
# 2524               0      334090               0          3604
# 3797               0      271841               0          6881
# 5070               0        8332               0            34
# 6343               0       48015               0           159
# ...              ...         ...             ...           ...
# 296587             0    11615051               0         43206
# 297860             0        3550               0             8
# 299133             0       11945               0          2159
# 300406             0      345058               0          4058
# 301679             0      265161               0          5695
#
# [237 rows x 9 columns]

# %%
df = df_last
fig = px.scatter_geo(df_last, locations="PAIS_ISO3", color="OMS_REGION",
                     hover_name="PAIS_NOM", size="MUERTES_ACUM")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8345fb45-45af-4835-b856-f490789b4258" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8345fb45-45af-4835-b856-f490789b4258")) {                    Plotly.newPlot(                        "8345fb45-45af-4835-b856-f490789b4258",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>OMS_REGION=EMRO<br>MUERTES_ACUM=%{marker.size}<br>PAIS_ISO3=%{location}<extra></extra>","hovertext":["Afghanistan","Bahrain","Djibouti","Egypt","Iran","Iraq","Jordan","Kuwait","Lebanon","Libya","Morocco","Palestine","Oman","Pakistan","Qatar","Saudi Arabia","Somalia","Sudan","Syria","Tunisia","United Arab Emirates","Yemen"],"legendgroup":"EMRO","locations":["AFG","BHR","DJI","EGY","IRN","IRQ","JOR","KWT","LBN","LBY","MAR","PSE","OMN","PAK","QAT","SAU","SOM","SDN","SYR","TUN","ARE","YEM"],"marker":{"color":"#636efa","size":[7919,1536,189,24830,146273,25375,14122,2570,10930,6437,16297,5708,4628,30656,690,9646,1361,5046,3163,29423,2349,2159],"sizemode":"area","sizeref":2817.88,"symbol":"circle"},"mode":"markers","name":"EMRO","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>OMS_REGION=EURO<br>MUERTES_ACUM=%{marker.size}<br>PAIS_ISO3=%{location}<extra></extra>","hovertext":["Albania","Andorra","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Faroe Islands","Finland","France","Georgia","Germany","Gibraltar","Greece","Greenland","Guernsey","Holy See (Vatican City State)","Hungary","Iceland","Ireland","Isle of Man","Israel","Italy","Jersey","Kazakhstan","Otros","Kyrgyzstan","Latvia","Liechtenstein","Lithuania","Luxembourg","Malta","Monaco","Montenegro","Netherlands","Macedonia","Norway","Poland","Portugal","Moldova","Romania","Russia","San Marino","Serbia","Slovakia","Slovenia","Spain","Sweden","Switzerland","Tajikistan","United Kingdom","Turkey","Turkmenistan","Ukraine","Uzbekistan"],"legendgroup":"EURO","locations":["ALB","AND","ARM","AUT","AZE","BLR","BEL","BIH","BGR","HRV","CYP","CZE","DNK","EST","FRO","FIN","FRA","GEO","DEU","GIB","GRC","GRL","GGY","VAT","HUN","ISL","IRL","IMN","ISR","ITA","JEY","KAZ","Z99","KGZ","LVA","LIE","LTU","LUX","MLT","MCO","MNE","NLD","MKD","NOR","POL","PRT","MDA","ROU","RUS","SMR","SRB","SVK","SVN","ESP","SWE","CHE","TJK","GBR","TUR","TKM","UKR","UZB"],"marker":{"color":"#EF553B","size":[3604,159,8750,22523,10277,7118,34360,16348,38337,18266,1364,42807,8721,2895,28,9907,167750,17091,174546,113,37116,21,67,0,48795,186,9015,116,12550,190588,161,19072,3208,1024,7353,87,9687,1000,859,67,2654,22986,9939,5556,119619,26792,12123,68193,399226,125,18056,21167,9399,121628,24460,14020,125,227524,101419,0,109840,1016],"sizemode":"area","sizeref":2817.88,"symbol":"circle"},"mode":"markers","name":"EURO","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>OMS_REGION=AFRO<br>MUERTES_ACUM=%{marker.size}<br>PAIS_ISO3=%{location}<extra></extra>","hovertext":["Algeria","Angola","Benin","Botswana","Burkina Faso","Burundi","Cape Verde","Cameroon","Central African Republic","Chad","Comoros","Congo (Brazzaville)","Cote d'Ivoire","Congo (Kinshasa)","Equatorial Guinea","Eritrea","Swaziland","Ethiopia","Gabon","Gambia","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritania","Mauritius","Mayotte","Mozambique","Namibia","Niger","Nigeria","Reunion","Rwanda","Saint Helena","Sao Tome and Principe","Senegal","Seychelles","Sierra Leone","South Africa","Sud\u00e1n del Sur","Togo","Uganda","Tanzania","Zambia","Zimbabwe"],"legendgroup":"AFRO","locations":["DZA","AGO","BEN","BWA","BFA","BDI","CPV","CMR","CAF","TCD", ...

# %% [markdown]
# # Acceso al dataSet de Vacunación **df_vacunation**

# %%
df_vacunation =pd.read_csv ('/content/TFM/Ficheros_Depurados/df_vacunation.csv')

df_vacunation.head(10)
# Out:
#             PAIS PAIS_ISO3     CONTINENTE ISO_CONTINENTE OMS_REGION  \
# 0        Algeria       DZA         Africa             AF       AFRO
# 1         Angola       AGO         Africa             AF       AFRO
# 2        Armenia       ARM           Asia             AS       EURO
# 3          Aruba       ABW  North America            NaN       AMRO
# 4         Brazil       BRA  South America             SA       AMRO
# 5   Burkina Faso       BFA         Africa             AF       AFRO
# 6     Costa Rica       CRI  North America            NaN       AMRO
# 7       Dominica       DMA  North America            NaN       AMRO
# 8        Finland       FIN         Europe             EU       EURO
# 9  French Guiana       GUF  South America             SA       AMRO
#
#   FUENTE_DATOS FECHA_ULT_ACTUALIZACION  TOTAL_VACUNACION_ACUM  \
# 0    REPORTING              04-09-2022             15267442.0
# 1    REPORTING              18-06-2023             25962530.0
# 2    REPORTING              04-06-2023              2158796.0
# 3    REPORTING              02-06-2023               216974.0
# 4    REPORTING              02-06-2023            513329718.0
# 5    REPORTING              19-03-2023              6674010.0
# 6    REPORTING              02-06-2023             13371989.0
# 7    REPORTING              02-06-2023                67647.0
# 8    REPORTING              11-06-2023             13262633.0
# 9    REPORTING              02-06-2023               242193.0
#
#    NPER_VACUNADAS_1DOSIS  TOTAL_VACUNACION_PER100  \
# 0                7840131                   34.817
# 1               15980639                   78.994
# 2                1122646                   72.900
# 3                  90449                  203.224
# 4              188746389                  241.499
# 5                5152110                   31.928
# 6                4641899                  262.499
# 7                  32995                   93.966
# 8                4547390                  240.000
# 9                 100299                   81.087
#
#    NPER_VACUNADAS_1DOSIS_PER100  NPER_VACUNADAS_DOSIS_FULL  \
# 0                        17.879                    6481186
# 1                        48.623                    9010599
# 2                        37.886                     996804
# 3                        84.717                      84297
# 4                        88.797                  171459392
# 5                        24.647                    4129254
# 6                        91.123                    4358863
# 7                        45.832                      30659
# 8                        82.301                    4364869
# 9                        33.581                      90464
#
#    NPER_VACUNADAS_DOSIS_FULL_PER100 FECHA_PRIMERA_VACUNA  \
# 0                            14.780           30-01-2021
# 1                            27.416           10-03-2021
# 2                            33.639           27-01-2021
# 3                            78.955           17-02-2021
# 4                            80.664           17-01-2021
# 5                            19.754           02-06-2021
# 6                            85.567           24-12-2020
# 7                            42.587           12-02-2021
# 8                            78.998           23-12-2020
# 9                            30.288           13-01-2021
#
#    N_TIPOS_VACUNAS_USADAS  NPER_CON_DOSIS_ADICIONAL  \
# 0                     4.0                  575651.0
# 1                     1.0                 2220003.0
# 2                    10.0                   45446.0
# 3                     2.0                   35659.0
# 4                     5.0               110382337.0
# 5                     3.0                       0.0
# 6                     3.0                 2957974.0
# 7                     5.0                    3993.0
# 8                     5.0                 3088223.0
# 9                     3.0                   46331.0
#
#    NPER_CON_DOSIS_ADIDICIONAL_PER100
# 0                              1.313
# 1                              6.755
# 2                              1.534
# 3                             33.399
# 4                             51.930
# 5                              0.000
# 6                             58.066
# 7                              5.547
# 8                             55.892
# 9                             15.512

# %% [markdown]
# Sustituir los valores "NaN" del campo **ISO_CONTINENTE** por **NA** que pertenece al Continente **North America"**

# %%
df_vacunation=df_vacunation.fillna('NA')
df_vacunation.head()
# Out:
#       PAIS PAIS_ISO3     CONTINENTE ISO_CONTINENTE OMS_REGION FUENTE_DATOS  \
# 0  Algeria       DZA         Africa             AF       AFRO    REPORTING
# 1   Angola       AGO         Africa             AF       AFRO    REPORTING
# 2  Armenia       ARM           Asia             AS       EURO    REPORTING
# 3    Aruba       ABW  North America             NA       AMRO    REPORTING
# 4   Brazil       BRA  South America             SA       AMRO    REPORTING
#
#   FECHA_ULT_ACTUALIZACION  TOTAL_VACUNACION_ACUM  NPER_VACUNADAS_1DOSIS  \
# 0              04-09-2022             15267442.0                7840131
# 1              18-06-2023             25962530.0               15980639
# 2              04-06-2023              2158796.0                1122646
# 3              02-06-2023               216974.0                  90449
# 4              02-06-2023            513329718.0              188746389
#
#    TOTAL_VACUNACION_PER100  NPER_VACUNADAS_1DOSIS_PER100  \
# 0                   34.817                        17.879
# 1                   78.994                        48.623
# 2                   72.900                        37.886
# 3                  203.224                        84.717
# 4                  241.499                        88.797
#
#    NPER_VACUNADAS_DOSIS_FULL  NPER_VACUNADAS_DOSIS_FULL_PER100  \
# 0                    6481186                            14.780
# 1                    9010599                            27.416
# 2                     996804                            33.639
# 3                      84297                            78.955
# 4                  171459392                            80.664
#
#   FECHA_PRIMERA_VACUNA  N_TIPOS_VACUNAS_USADAS  NPER_CON_DOSIS_ADICIONAL  \
# 0           30-01-2021                     4.0                  575651.0
# 1           10-03-2021                     1.0                 2220003.0
# 2           27-01-2021                    10.0                   45446.0
# 3           17-02-2021                     2.0                   35659.0
# 4           17-01-2021                     5.0               110382337.0
#
#    NPER_CON_DOSIS_ADIDICIONAL_PER100
# 0                              1.313
# 1                              6.755
# 2                              1.534
# 3                             33.399
# 4                             51.930

# %% [markdown]
# Creación de Pivot Table para agrupar el Total de Vacunaciones de dosis completa por Continente

# %%
#Creamos una Pivot table que sume todas las vacunaciones de dosis completa por Continente
df_vacunation_continente = pd.pivot_table(
    df_vacunation,
    values = 'NPER_VACUNADAS_DOSIS_FULL',
    index = ['CONTINENTE'],
    aggfunc=sum,
    fill_value=0
    ).sort_values(by='NPER_VACUNADAS_DOSIS_FULL', ascending=True)

#Cambiamos el nombre de la columna New NPER_VACUNADAS_DOSIS_FULL a TOTAL VACUNACIONES DOSIS COMPLETA
df_vacunation_continente = df_vacunation_continente.rename(columns={ 'NPER_VACUNADAS_DOSIS_FULL':'TOTAL PERSONAS VACUNADAS DOSIS COMPLETA' })
df_vacunation_continente
# Out:
#                 TOTAL PERSONAS VACUNADAS DOSIS COMPLETA
# CONTINENTE
# Sin Determinar                                  1670741
# Oceania                                        28230012
# South America                                 334670432
# North America                                 393649400
# Africa                                        447834392
# Europe                                        495901757
# Asia                                         3435905038

# %% [markdown]
# Creación de Pivot Table para agrupar el Total de Vacunaciones de dosis adicional por Continente

# %%
#Creamos una Pivot table que sume todas las vacunaciones de dosis Adicional por Continente
df_vacunation_continente_adicional = pd.pivot_table(
    df_vacunation,
    values = 'NPER_CON_DOSIS_ADICIONAL',
    index = ['CONTINENTE'],
    aggfunc=sum,
    fill_value=0
    ).sort_values(by='NPER_CON_DOSIS_ADICIONAL', ascending=True)

#Cambiamos el nombre de la columna New NPER_CON_DOSIS_ADICIONAL a TOTAL VACUNACIONES DOSIS ADICIONAL
df_vacunation_continente_adicional = df_vacunation_continente_adicional.rename(columns={ 'NPER_CON_DOSIS_ADICIONAL':'TOTAL PERSONAS VACUNADAS CON DOSIS ADICIONAL' })
df_vacunation_continente_adicional
# Out:
#                 TOTAL PERSONAS VACUNADAS CON DOSIS ADICIONAL
# CONTINENTE
# Sin Determinar                                        460418
# Oceania                                             17928436
# Africa                                              84548922
# South America                                      208659287
# North America                                      225164102
# Europe                                             260422262
# Asia                                              1676144307

# %% [markdown]
# Importamos la librería de Gráficos **Matplot**

# %% [markdown]
# Agrupación del dataSet df_vacunation por Continente y obtenemos un Gráfico de barras apiladas de Vacunaciones con Dosis Completa y Dosis Adicional por Continente

# %%
df_vacunation_1 = df_vacunation.groupby('CONTINENTE')

# %%
#Obtenemos los datos de la pivot table y obtenemos Gráfico

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(tight_layout=True,figsize=(16,8))
scale = 'linear'

ax.set_yscale(scale)

ax.set_title(f'Total de Vacunaciones por cada 100 habitantes por Continente ', fontsize='large')

df_vacunation_1.sum()['NPER_VACUNADAS_DOSIS_FULL'].plot(kind='bar', rot=15,color='green')
df_vacunation_1.sum()['NPER_CON_DOSIS_ADICIONAL'].plot(kind='bar', rot=15,color='orange').legend(loc='best',fontsize=10)

#Leyendas en los ejes
ax.set_xlabel(f'CONTINENTE', fontsize='medium')
ax.set_ylabel(f'N Personas Vacunadas', fontsize='medium')
# Out:
# <ipython-input-26-8818b1b87ac1>:13: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# <ipython-input-26-8818b1b87ac1>:14: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# Text(0, 0.5, 'N Personas Vacunadas')

# %% [markdown]
# Top 10 de paises de Asia con Personas Vacunadas con Dosis Completa

# %%
#Creamos una Pivot table que sume todas las vacunaciones por Paises del Continente Asiatico
df_vacunation_continente_asia=df_vacunation[df_vacunation['CONTINENTE']== "Asia"]
df_vacunation_continente_asia_top10 = df_vacunation_continente_asia.sort_values('NPER_VACUNADAS_DOSIS_FULL', ascending=False).head(10)

df_vacunation_continente_asia_top10 = pd.pivot_table(
    df_vacunation_continente_asia_top10,
    values = 'NPER_VACUNADAS_DOSIS_FULL',
    index = ['PAIS'],
    aggfunc=sum,
    fill_value=0
    ).sort_values(by='NPER_VACUNADAS_DOSIS_FULL', ascending=True)

#Cambiamos el nombre de la columna New test a Pruebas
df_vacunation_continente_asia_top10 = df_vacunation_continente_asia_top10.rename(columns={ 'NPER_VACUNADAS_DOSIS_FULL':'TOTAL VACUNACIONES DOSIS COMPLETA' })
df_vacunation_continente_asia_top10.head(10)
# Out:
#                             TOTAL VACUNACIONES DOSIS COMPLETA
# PAIS
# Thailand                                             54181443
# Iran (Islamic Republic of)                           58575727
# Philippines                                          78443972
# Viet Nam                                             85958364
# Japan                                               103392920
# Pakistan                                            140466099
# Bangladesh                                          141208849
# Indonesia                                           174893201
# India                                               952120865
# China                                              1284413713

# %%
#Obtenemos los datos de la pivot table y obtenemos Gráfico
axes = df_vacunation_continente_asia_top10.plot(kind='barh', rot=15)
#Leyendas en los ejes
axes.set_xlabel('N PER VACUNADAS EN ASIA CON DOSIS COMPLETA')
axes.set_ylabel('Top 10 Paises del Continente Asiatico')

fig = axes.get_figure()
#Cambiamos tamaño de gráfica
fig.set_size_inches(14,7)

#Iteramos en cada barra para pintar sus valores en la gráfica
for barh in axes.patches:
    axes.annotate(
      "{:,}".format( barh.get_height() ),
      (barh.get_x() * 1.0005, barh.get_height() * 1.005)
    )

# %% [markdown]
# Gráficos con la librería **Plotly**

# %% [markdown]
# Top 10 Paises con Total de Vacunaciones

# %%
df_vacunation_paises_top10 = df_vacunation[['PAIS','NPER_VACUNADAS_DOSIS_FULL']].sort_values(by=['NPER_VACUNADAS_DOSIS_FULL'],ascending=False).head(10)
fig = px.bar(df_vacunation_paises_top10, x='NPER_VACUNADAS_DOSIS_FULL', y='PAIS', color='PAIS', title='Top 10 Paises con mayor Vacunación')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c47f09a5-744c-4d19-86a5-7975875aed2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c47f09a5-744c-4d19-86a5-7975875aed2b")) {                    Plotly.newPlot(                        "c47f09a5-744c-4d19-86a5-7975875aed2b",                        [{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"h","showlegend":true,"textposition":"auto","x":[1284413713],"xaxis":"x","y":["China"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"India","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[952120865],"xaxis":"x","y":["India"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"United States of America","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"United States of America","offsetgroup":"United States of America","orientation":"h","showlegend":true,"textposition":"auto","x":[227948938],"xaxis":"x","y":["United States of America"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"h","showlegend":true,"textposition":"auto","x":[174893201],"xaxis":"x","y":["Indonesia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"h","showlegend":true,"textposition":"auto","x":[171459392],"xaxis":"x","y":["Brazil"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"h","showlegend":true,"textposition":"auto","x":[141208849],"xaxis":"x","y":["Bangladesh"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[140466099],"xaxis":"x","y":["Pakistan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Japan","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"h","showlegend":true,"textposition":"auto","x":[103392920],"xaxis":"x","y":["Japan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Viet Nam","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Viet Nam","offsetgroup":"Viet Nam","orientation":"h","showlegend":true,"textposition":"auto","x":[85958364],"xaxis":"x","y":["Viet Nam"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Mexico","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Mexico","offsetgroup":"Mexico","orientation":"h","showlegend":true,"textposi ...

# %% [markdown]
# Top 10 Paises con menor Vacunación

# %%
df_vacunation_paises_button10 = df_vacunation[['PAIS','NPER_VACUNADAS_DOSIS_FULL']].sort_values(by=['NPER_VACUNADAS_DOSIS_FULL'],ascending=False).tail(10)
fig = px.bar(df_vacunation_paises_button10, x='NPER_VACUNADAS_DOSIS_FULL', y='PAIS',color ='PAIS', title='Top 10 Paises con menor Vacunación con Dosis Completa')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cd22f0fb-1ee5-4109-a7e3-8e32d245e799" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd22f0fb-1ee5-4109-a7e3-8e32d245e799")) {                    Plotly.newPlot(                        "cd22f0fb-1ee5-4109-a7e3-8e32d245e799",                        [{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Wallis and Futuna","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Wallis and Futuna","offsetgroup":"Wallis and Futuna","orientation":"h","showlegend":true,"textposition":"auto","x":[6803],"xaxis":"x","y":["Wallis and Futuna"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Saint Helena, Ascension and Tristan da Cunha","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Saint Helena, Ascension and Tristan da Cunha","offsetgroup":"Saint Helena, Ascension and Tristan da Cunha","orientation":"h","showlegend":true,"textposition":"auto","x":[3531],"xaxis":"x","y":["Saint Helena, Ascension and Tristan da Cunha"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Falkland Islands (Malvinas)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Falkland Islands (Malvinas)","offsetgroup":"Falkland Islands (Malvinas)","orientation":"h","showlegend":true,"textposition":"auto","x":[2976],"xaxis":"x","y":["Falkland Islands (Malvinas)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Tokelau","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Tokelau","offsetgroup":"Tokelau","orientation":"h","showlegend":true,"textposition":"auto","x":[2203],"xaxis":"x","y":["Tokelau"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Montserrat","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Montserrat","offsetgroup":"Montserrat","orientation":"h","showlegend":true,"textposition":"auto","x":[1952],"xaxis":"x","y":["Montserrat"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Sint Eustatius","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Sint Eustatius","offsetgroup":"Sint Eustatius","orientation":"h","showlegend":true,"textposition":"auto","x":[1686],"xaxis":"x","y":["Sint Eustatius"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Saba","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Saba","offsetgroup":"Saba","orientation":"h","showlegend":true,"textposition":"auto","x":[1667],"xaxis":"x","y":["Saba"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Niue","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Niue","offsetgroup":"Niue","orientation":"h","showlegend":true,"textposition":"auto","x":[1635],"xaxis":"x","y":["Niue"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>NPER_VACUNADAS_DOSIS_FULL=%{x}<extra></extra>","legendgroup":"Pitcairn Islands","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pitcairn Islands","offsetgroup":"Pitcairn Islands","orientation":"h","showlegend":true,"textposition":"auto","x":[47],"xaxis":"x","y":["Pitcairn Islands"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PAIS=%{y}<br>N ...

# %%
fig_recovered = px.bar(df_vacunation, x = "CONTINENTE", y = "NPER_VACUNADAS_DOSIS_FULL_PER100", color = "CONTINENTE", title = "Total de Personas Vacunadas por cada 100 habitantes")
fig_recovered.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="047a28e7-477f-4a26-8e58-49c86439c985" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("047a28e7-477f-4a26-8e58-49c86439c985")) {                    Plotly.newPlot(                        "047a28e7-477f-4a26-8e58-49c86439c985",                        [{"alignmentgroup":"True","hovertemplate":"CONTINENTE=%{x}<br>NPER_VACUNADAS_DOSIS_FULL_PER100=%{y}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa","Africa"],"xaxis":"x","y":[14.78,27.416,19.754,11.568,44.265,18.772,54.167,22.625,70.738,11.828,37.303,20.625,73.768,9.256,33.08,41.371,36.834,43.79,21.28,8.617,35.473,51.451,37.971,22.311,17.989,21.955,22.532,30.597,53.848,49.76,37.035,11.854,46.115,35.986,27.121,85.561,84.97,28.555,33.857,37.705,45.662,16.078,15.255,0.0,32.73,17.943,63.727,68.243,51.098,35.598,80.293,58.162,0.305,55.526,58.15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"CONTINENTE=%{x}<br>NPER_VACUNADAS_DOSIS_FULL_PER100=%{y}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia"],"xaxis":"x","y":[33.639,35.371,85.122,64.688,59.703,63.59,87.707,29.748,63.941,69.739,83.705,72.098,68.994,98.998,73.057,68.896,99.008,54.751,85.743,102.092,44.676,71.255,81.749,20.428,66.659,55.684,2.663,34.833,54.212,73.888,19.752,48.206,87.826,87.299,73.776,69.612,78.347,78.234,77.624,60.935,42.4,71.585,83.812,89.697,13.476,88.309],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"CONTINENTE=%{x}<br>NPER_VACUNADAS_DOSIS_FULL_PER100=%{y}<extra></extra>","legendgroup":"North America","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America","North America"],"xaxis":"x","y":[78.955,85.567,42.587,3.073,50.76,69.191,42.46,53.949,55.682,76.529,64.401,82.962,34.69,60.393,67.74,39.048,68.866,88.432,61.48,36.513,58.064,28.513,67.834,51.374,79.317,63.703,25.625,38.782,63.092,73.567,93.972,56.193,39.786,29.936,92.307,92.341],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"CONTINENTE=%{x}<br>NPER_VACUNADAS_DOSIS_FULL_PER100=%{y ...

# %% [markdown]
# Tipos de Vacunación

# %% [markdown]
# Tipos de Vacunas utilizadas en más paises

# %%
df_vacunation_tipo =pd.read_csv ('/content/TFM/Ficheros_Depurados/df_vacunation_tipo.csv')

df_vacunation_tipo.head(10)
# Out:
#   PAIS_ISO3     CONTINENTE ISO_continente                NOMBRE_VACUNA  \
# 0       SHN         Africa             AF        AstraZeneca - AZD1222
# 1       GRL  North America            NaN          Moderna - mRNA-1273
# 2       FRO         Europe             EU          Moderna - mRNA-1273
# 3       FRO         Europe             EU  Pfizer BioNTech - Comirnaty
# 4       BIH         Europe             EU        AstraZeneca - AZD1222
# 5       BIH         Europe             EU  Pfizer BioNTech - Comirnaty
# 6       BIH         Europe             EU          Sinovac - CoronaVac
# 7       JEY         Europe             EU          Moderna - mRNA-1273
# 8       JEY         Europe             EU        AstraZeneca - AZD1222
# 9       JEY         Europe             EU  Pfizer BioNTech - Comirnaty
#
#   NOMBRE_TIPO_VACUNA  NOMBRE_COMPAÑIA FECHA_AUTORIZACION  \
# 0            AZD1222      AstraZeneca                  0
# 1          mRNA-1273          Moderna                  0
# 2          mRNA-1273          Moderna                  0
# 3          Comirnaty  Pfizer BioNTech                  0
# 4            AZD1222      AstraZeneca                  0
# 5          Comirnaty  Pfizer BioNTech                  0
# 6          Coronavac          Sinovac                  0
# 7          mRNA-1273          Moderna                  0
# 8            AZD1222      AstraZeneca                  0
# 9          Comirnaty  Pfizer BioNTech                  0
#
#   FECHA_INICIO_VACUNACION FUENTE_DATOS
# 0                       0         OWID
# 1                       0         OWID
# 2                       0         OWID
# 3                       0         OWID
# 4                       0         OWID
# 5                       0         OWID
# 6                       0         OWID
# 7                       0         OWID
# 8                       0         OWID
# 9                       0         OWID

# %%
number_of_vaccines = df_vacunation_tipo.groupby('NOMBRE_COMPAÑIA')['PAIS_ISO3'].nunique()

# %%
number_of_vaccines.sort_values(ascending=True).plot(kind="barh", color="g")
# Out:
# <Axes: ylabel='NOMBRE_COMPAÑIA'>
