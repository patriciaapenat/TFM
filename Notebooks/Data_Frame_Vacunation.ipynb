# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciaapenat/TFM/blob/main/Notebooks/Data_Frame_Vacunation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/patriciaapenat/TFM.git
# Out:
# Cloning into 'TFM'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 37 (delta 13), reused 16 (delta 6), pack-reused 0
# Unpacking objects: 100% (37/37), 459.06 KiB | 4.33 MiB/s, done.

# %%
import pandas as pd
import numpy as np
import datetime

# %%
# Acceso a los datasets de la OMS:
#df_covid_daily = pd.read_csv('https://covid19.who.int/WHO-COVID-19-global-data.csv')
#df_last_covid = pd.read_csv('https://covid19.who.int/WHO-COVID-19-global-table-data.csv')
df_vacunation =pd.read_csv ('https://covid19.who.int/who-data/vaccination-data.csv')
#df_vacunation_Meta =pd.read_csv ('https://covid19.who.int/who-data/vaccination-metadata.csv')

# %%
df_vacunation
# Out:
#                   COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0                 Albania  ALB       EURO   REPORTING   2023-05-14
# 1                   Chile  CHL       AMRO   REPORTING   2023-06-02
# 2                   Congo  COG       AFRO   REPORTING   2022-07-31
# 3           Côte d’Ivoire  CIV       AFRO   REPORTING   2023-02-19
# 4                 Denmark  DNK       EURO   REPORTING   2023-06-11
# ..                    ...  ...        ...         ...          ...
# 224                 Spain  ESP       EURO   REPORTING   2023-06-11
# 225           Switzerland  CHE       EURO   REPORTING   2023-06-11
# 226  Syrian Arab Republic  SYR       EMRO   REPORTING   2023-04-18
# 227           Timor-Leste  TLS      SEARO   REPORTING   2023-06-26
# 228              Viet Nam  VNM       WPRO   REPORTING   2023-06-08
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0             3080679.0                        1348396
# ...

# %%
df_vacunation.to_csv('/content/TFM/Ficheros_depurados/df_vacunation.csv')
