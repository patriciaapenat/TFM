# %% [markdown]
# # Montaje de la base de datos

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Data on testing for COVID-19 by week and country.

# %%
testing = pd.read_excel("C:/Users/Patricia/Downloads/Limpieza de Archivos Fuente/Data on testing for COVID-19 by week and country/Data on testing for COVID-19 by week and country.xlsx")

# %%
testing
# Out:
#       country country_code year_week     level region region_name  new_cases  \
# 0     Austria           AT  2020-W01  national     AT     Austria        NaN
# 1     Austria           AT  2020-W02  national     AT     Austria        NaN
# 2     Austria           AT  2020-W03  national     AT     Austria        NaN
# 3     Austria           AT  2020-W04  national     AT     Austria        NaN
# 4     Austria           AT  2020-W05  national     AT     Austria        NaN
# ...       ...          ...       ...       ...    ...         ...        ...
# 5006   Sweden           SE  2023-W06  national     SE      Sweden     1042.0
# 5007   Sweden           SE  2023-W07  national     SE      Sweden      813.0
# 5008   Sweden           SE  2023-W08  national     SE      Sweden      646.0
# 5009   Sweden           SE  2023-W09  national     SE      Sweden      731.0
# 5010   Sweden           SE  2023-W10  national     SE      Sweden      871.0
#
# ...

# %%
testing.isna().sum()
# Out:
# country                  0
# country_code             0
# year_week                0
# level                    0
# region                   0
# region_name              0
# new_cases              821
# tests_done             790
# population               0
# testing_rate           790
# positivity_rate        835
# testing_data_source    790
# dtype: int64

# %%
testing.shape
# Out:
# (5011, 12)

# %%
testing.dtypes
# Out:
# country                 object
# country_code            object
# year_week               object
# level                   object
# region                  object
# region_name             object
# new_cases              float64
# tests_done             float64
# population               int64
# testing_rate           float64
# positivity_rate        float64
# testing_data_source     object
# dtype: object

# %%
for columna in testing.columns:
    longitud_maxima = testing[columna].astype(str).str.len().max()
    print(f"Longitud máxima en la columna '{columna}': {longitud_maxima}")
# Out:
# Longitud máxima en la columna 'country': 13
# Longitud máxima en la columna 'country_code': 2
# Longitud máxima en la columna 'year_week': 8
# Longitud máxima en la columna 'level': 8
# Longitud máxima en la columna 'region': 2
# Longitud máxima en la columna 'region_name': 13
# Longitud máxima en la columna 'new_cases': 9
# Longitud máxima en la columna 'tests_done': 9
# Longitud máxima en la columna 'population': 8
# Longitud máxima en la columna 'testing_rate': 19
# Longitud máxima en la columna 'positivity_rate': 18
# Longitud máxima en la columna 'testing_data_source': 11

# %% [markdown]
# # datos_combinados_csse_covid_19_daily_reports_us

# %%
dailyus = pd.read_csv("C:/Users/Patricia/Downloads/Limpieza de Archivos Fuente/Csse_covid_19_daily_reports_us/datos_combinados_csse_covid_19_daily_reports_us.csv", sep = ',')

# %%
dailyus
# Out:
#        Province_State Country_Region          Last_Update      Lat     Long_  \
# 0             Alabama             US  2021-01-02 05:30:44  32.3182  -86.9023
# 1              Alaska             US  2021-01-02 05:30:44  61.3707 -152.4044
# 2      American Samoa             US  2021-01-02 05:30:44 -14.2710 -170.1320
# 3             Arizona             US  2021-01-02 05:30:44  33.7298 -111.4312
# 4            Arkansas             US  2021-01-02 05:30:44  34.9697  -92.3731
# ...               ...            ...                  ...      ...       ...
# 61609        Virginia             US  2023-01-01 04:31:23  37.7693  -78.1700
# 61610      Washington             US  2023-01-01 04:31:23  47.4009 -121.4905
# 61611   West Virginia             US  2023-01-01 04:31:23  38.4912  -80.9545
# 61612       Wisconsin             US  2023-01-01 04:31:23  44.2685  -89.6165
# 61613         Wyoming             US  2023-01-01 04:31:23  42.7560 -107.3025
#
# ...

# %%
dailyus.isna().sum()
# Out:
# Province_State              0
# Country_Region              0
# Last_Update                19
# Lat                      2142
# Long_                    2142
# Confirmed                   0
# Deaths                      0
# Recovered               46492
# Active                  46492
# FIPS                       19
# Incident_Rate            2142
# Total_Test_Results      24977
# People_Hospitalized     56485
# Case_Fatality_Ratio     12587
# UID                         0
# ISO3                        0
# Testing_Rate            15693
# Hospitalization_Rate    56485
# Date                     9860
# People_Tested           49798
# Mortality_Rate          49587
# dtype: int64

# %%
dailyus.shape
# Out:
# (61614, 21)

# %%
for columna in dailyus.columns:
    longitud_maxima = dailyus[columna].astype(str).str.len().max()
    print(f"Longitud máxima en la columna '{columna}': {longitud_maxima}")
# Out:
# Longitud máxima en la columna 'Province_State': 24
# Longitud máxima en la columna 'Country_Region': 2
# Longitud máxima en la columna 'Last_Update': 19
# Longitud máxima en la columna 'Lat': 7
# Longitud máxima en la columna 'Long_': 9
# Longitud máxima en la columna 'Confirmed': 8
# Longitud máxima en la columna 'Deaths': 6
# Longitud máxima en la columna 'Recovered': 9
# Longitud máxima en la columna 'Active': 9
# Longitud máxima en la columna 'FIPS': 7
# Longitud máxima en la columna 'Incident_Rate': 18
# Longitud máxima en la columna 'Total_Test_Results': 11
# Longitud máxima en la columna 'People_Hospitalized': 7
# Longitud máxima en la columna 'Case_Fatality_Ratio': 18
# Longitud máxima en la columna 'UID': 10
# Longitud máxima en la columna 'ISO3': 3
# Longitud máxima en la columna 'Testing_Rate': 22
# Longitud máxima en la columna 'Hospitalization_Rate': 18
# Longitud máxima en la columna 'Date': 10
# Longitud máxima en la columna 'People_Tested': 10
# ...

# %% [markdown]
# # Data on hospital and ICU admission rates and current occupancy for COVID-19

# %%
icu = pd.read_csv("C:/Users/Patricia/Downloads/Limpieza de Archivos Fuente/ICU/ICU.csv")

# %%
icu
# Out:
#        country                           indicator        date year_week  \
# 0      Austria            Daily hospital occupancy  2020-04-01  2020-W14
# 1      Austria            Daily hospital occupancy  2020-04-02  2020-W14
# 2      Austria            Daily hospital occupancy  2020-04-03  2020-W14
# 3      Austria            Daily hospital occupancy  2020-04-04  2020-W14
# 4      Austria            Daily hospital occupancy  2020-04-05  2020-W14
# ...        ...                                 ...         ...       ...
# 27272   Sweden  Weekly new ICU admissions per 100k  2023-04-23  2023-W16
# 27273   Sweden  Weekly new ICU admissions per 100k  2023-04-30  2023-W17
# 27274   Sweden  Weekly new ICU admissions per 100k  2023-05-07  2023-W18
# 27275   Sweden  Weekly new ICU admissions per 100k  2023-05-14  2023-W19
# 27276   Sweden  Weekly new ICU admissions per 100k  2023-05-21  2023-W20
#
#             value                           source  url
# ...

# %%
icu.isna().sum()
# Out:
# country          0
# indicator        0
# date             0
# year_week        0
# value            0
# source           0
# url          27277
# dtype: int64

# %%
for columna in icu.columns:
    longitud_maxima = icu[columna].astype(str).str.len().max()
    print(f"Longitud máxima en la columna '{columna}': {longitud_maxima}")
# Out:
# Longitud máxima en la columna 'country': 13
# Longitud máxima en la columna 'indicator': 39
# Longitud máxima en la columna 'date': 10
# Longitud máxima en la columna 'year_week': 8
# Longitud máxima en la columna 'value': 18
# Longitud máxima en la columna 'source': 49
# Longitud máxima en la columna 'url': 3

# %% [markdown]
# # Vaccination metadata

# %%
vaccmeta = pd.read_csv("C:/Users/Patricia/Downloads/Limpieza de Archivos Fuente/Vaccination metadata/Vaccination metadata.csv")

# %%
vaccmeta
# Out:
#      ISO3                                       VACCINE_NAME  \
# 0     SHN                              AstraZeneca - AZD1222
# 1     GRL                                Moderna - mRNA-1273
# 2     FRO                                Moderna - mRNA-1273
# 3     FRO                        Pfizer BioNTech - Comirnaty
# 4     BIH                              AstraZeneca - AZD1222
# ...   ...                                                ...
# 1095  AND  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1096  DEU  Moderna – Spikevax Bivalent Original/Omicron  ...
# 1097  SVN  Moderna – Spikevax Bivalent Original/Omicron  ...
# 1098  DEU  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1099  SVN  Pfizer BioNTech - Comirnaty Bivalent Original/...
#
#                                            PRODUCT_NAME     COMPANY_NAME  \
# 0                                               AZD1222      AstraZeneca
# 1                                             mRNA-1273          Moderna
# ...

# %%
vaccmeta.isna().sum()
# Out:
# ISO3                     0
# VACCINE_NAME             0
# PRODUCT_NAME             1
# COMPANY_NAME            47
# AUTHORIZATION_DATE     610
# START_DATE             286
# END_DATE              1100
# COMMENT               1100
# DATA_SOURCE              0
# dtype: int64

# %%
vaccmeta.shape

# %%
for columna in vaccmeta.columns:
    longitud_maxima = vaccmeta[columna].astype(str).str.len().max()
    print(f"Longitud máxima en la columna '{columna}': {longitud_maxima}")
# Out:
# Longitud máxima en la columna 'ISO3': 3
# Longitud máxima en la columna 'VACCINE_NAME': 63
# Longitud máxima en la columna 'PRODUCT_NAME': 63
# Longitud máxima en la columna 'COMPANY_NAME': 49
# Longitud máxima en la columna 'AUTHORIZATION_DATE': 10
# Longitud máxima en la columna 'START_DATE': 10
# Longitud máxima en la columna 'END_DATE': 3
# Longitud máxima en la columna 'COMMENT': 3
# Longitud máxima en la columna 'DATA_SOURCE': 9

# %% [markdown]
# # Vaccination data

# %%
vacc = pd.read_csv("C:/Users/Patricia/Downloads/Limpieza de Archivos Fuente/Vaccination data/Vaccination data.csv")

# %%
vacc
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2023-06-11
# 1              Albania  ALB       EURO   REPORTING   2023-05-14
# 2              Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3       American Samoa  ASM       WPRO   REPORTING   2023-03-29
# 4              Andorra  AND       EURO   REPORTING   2023-04-09
# ..                 ...  ...        ...         ...          ...
# 224           Viet Nam  VNM       WPRO   REPORTING   2023-06-01
# 225  Wallis and Futuna  WLF       WPRO   REPORTING   2023-01-23
# 226              Yemen  YEM       EMRO   REPORTING   2023-04-18
# 227             Zambia  ZMB       AFRO   REPORTING   2023-04-09
# 228           Zimbabwe  ZWE       AFRO   REPORTING   2023-05-14
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0            20000706.0                       16978090
# 1             3080679.0                        1348396
# ...

# %%
vacc.isna().sum()
# Out:
# Name                                                              1
# WHO Region                                                        0
# Cases - cumulative total                                          1
# Cases - cumulative total per 100000 population                    0
# Cases - newly reported in last 7 days                             1
# Cases - newly reported in last 7 days per 100000 population       0
# Cases - newly reported in last 24 hours                           0
# Deaths - cumulative total                                         1
# Deaths - cumulative total per 100000 population                   0
# Deaths - newly reported in last 7 days                            1
# Deaths - newly reported in last 7 days per 100000 population      0
# Deaths - newly reported in last 24 hours                        238
# dtype: int64

# %%
vacc.shape
# Out:
# (238, 12)

# %%
for columna in vacc.columns:
    longitud_maxima = vacc[columna].astype(str).str.len().max()
    print(f"Longitud máxima en la columna '{columna}': {longitud_maxima}")
# Out:
# Longitud máxima en la columna 'Name': 21
# Longitud máxima en la columna 'WHO Region': 9
# Longitud máxima en la columna 'Cases - cumulative total': 16
# Longitud máxima en la columna 'Cases - cumulative total per 100000 population': 6
# Longitud máxima en la columna 'Cases - newly reported in last 7 days': 17
# Longitud máxima en la columna 'Cases - newly reported in last 7 days per 100000 population': 4
# Longitud máxima en la columna 'Cases - newly reported in last 24 hours': 7
# Longitud máxima en la columna 'Deaths - cumulative total': 17
# Longitud máxima en la columna 'Deaths - cumulative total per 100000 population': 4
# Longitud máxima en la columna 'Deaths - newly reported in last 7 days': 18
# Longitud máxima en la columna 'Deaths - newly reported in last 7 days per 100000 population': 2
# Longitud máxima en la columna 'Deaths - newly reported in last 24 hours': 3

# %% [markdown]
# # Latest reported counts of cases and deaths

# %%
casesanddeaths = pd.read_csv("C:/Users/Patricia/Downloads/Limpieza de Archivos Fuente/Latest reported counts of cases and deaths/Latest reported counts of cases and deaths.csv")

# %%
casesanddeaths
# Out:
#                                                   Name  WHO Region  \
# Global                                             NaN   761402282
# United States of America                      Americas   102697566
# China                                  Western Pacific    99238143
# India                                  South-East Asia    44707525
# France                                          Europe    38677413
# ...                                                ...         ...
# Holy See                                        Europe          26
# Tokelau                                Western Pacific           5
# Pitcairn Islands                       Western Pacific           4
# Democratic People's Republic of Korea  South-East Asia           0
# Turkmenistan                                    Europe           0
#
#                                        Cases - cumulative total  \
# Global                                              9768.405152
# ...

# %%
casesanddeaths.isna().sum()
# Out:
# Name                                                              1
# WHO Region                                                        0
# Cases - cumulative total                                          1
# Cases - cumulative total per 100000 population                    0
# Cases - newly reported in last 7 days                             1
# Cases - newly reported in last 7 days per 100000 population       0
# Cases - newly reported in last 24 hours                           0
# Deaths - cumulative total                                         1
# Deaths - cumulative total per 100000 population                   0
# Deaths - newly reported in last 7 days                            1
# Deaths - newly reported in last 7 days per 100000 population      0
# Deaths - newly reported in last 24 hours                        238
# dtype: int64

# %%
casesanddeaths.shape
# Out:
# (238, 12)

# %%
for columna in casesanddeaths.columns:
    longitud_maxima = casesanddeaths[columna].astype(str).str.len().max()
    print(f"Longitud máxima en la columna '{columna}': {longitud_maxima}")
# Out:
# Longitud máxima en la columna 'Name': 21
# Longitud máxima en la columna 'WHO Region': 9
# Longitud máxima en la columna 'Cases - cumulative total': 16
# Longitud máxima en la columna 'Cases - cumulative total per 100000 population': 6
# Longitud máxima en la columna 'Cases - newly reported in last 7 days': 17
# Longitud máxima en la columna 'Cases - newly reported in last 7 days per 100000 population': 4
# Longitud máxima en la columna 'Cases - newly reported in last 24 hours': 7
# Longitud máxima en la columna 'Deaths - cumulative total': 17
# Longitud máxima en la columna 'Deaths - cumulative total per 100000 population': 4
# Longitud máxima en la columna 'Deaths - newly reported in last 7 days': 18
# Longitud máxima en la columna 'Deaths - newly reported in last 7 days per 100000 population': 2
# Longitud máxima en la columna 'Deaths - newly reported in last 24 hours': 3
